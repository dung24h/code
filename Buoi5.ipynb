# %%
#W5A
def max_of_two(a, b):
    if(a>b): return a
    return b

a, b=map(int, input().split())
print(max_of_two(a, b))

# %%
#W5A10

def rev(s):
    return (ord(s)-97)

s, t=input().split()
l=len(s)
x=['0']*27
y=list(x)
i=0
ok=1

while(i<l):
    if(x[rev(s[i])]=='0'):
        if(y[rev(t[i])]=='0'):
            x[rev(s[i])]=t[i]
            y[rev(t[i])]=s[i]

        else:
            ok=0
            break
    else:
        if(y[rev(t[i])]=='0'):
            ok=0
            if(i==3): print(y[rev('e')])
            break
        elif(x[rev(s[i])]==y[rev(t[i])]):
            continue

    
    i+=1


if(ok): print('True')
else: print('False')
