# %% [markdown]
# # Bài từ file: A1

# %%
print('Hello World!')

# %% [markdown]
# # Bài từ file: A10

# %%
a, b, c=map(str, input().split())
print(c, b, a)

# %% [markdown]
# # Bài từ file: A11

# %%
h, m=map(float, input().split())
s=h*3600+m*60
print(s)

# %% [markdown]
# # Bài từ file: A12

# %%
n=int(input())
res=n*n*6
print(res)

# %% [markdown]
# # Bài từ file: A13

# %%
a, b=map(int, input().split())
c=a*b
print(c%10)

# %% [markdown]
# # Bài từ file: A14

# %%
a, b=map(int, input().split())
a, b=b, a
print(a, b)

# %% [markdown]
# # Bài từ file: A15

# %%
n=int(input())
res=6*n*(n-1)+1
print(res)

# %% [markdown]
# # Bài từ file: A16

# %%
print('Spring')
print('Summer')
print('Autumn')
print('Winter')

# %% [markdown]
# # Bài từ file: A17

# %%
print("*")
print("***")
print("*****")

# %% [markdown]
# # Bài từ file: A18

# %%
print('''
	###   # #    ###  ###  
     #    #  #    #    #  
     #    #   #   #    #  
     #    #  #    #    #  
     #    # #     #    #
          ''')

# %% [markdown]
# # Bài từ file: A19

# %%
print('Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday')

# %% [markdown]
# # Bài từ file: A2

# %%
n=input('Nhap ten nguoi dung:')
print('Xin chao dai ca',n)

# %% [markdown]
# # Bài từ file: A20

# %%
print('January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember')

# %% [markdown]
# # Bài từ file: A21

# %%
a, b, c=input().split()
print(f"xin chao {a} {b} {c}" )

# %% [markdown]
# # Bài từ file: A3

# %%
a, b=map(int, input().split())
tong=a+b
hieu=a-b;
tich=a*b
thuong=int(a/b)
du=a%b
thuc=a/b
print(tong, hieu, tich, thuong, du, '{:.2f}'.format(a))

# %% [markdown]
# # Bài từ file: A4

# %%
def TB(a, b, c, d, x, y):
	tb=((a+b+c)+(d+x)*2+y*3)/10
	return tb

# %%
a1, a2, a3, a4, a5, a6=map(int, input().split())
diem=TB(a1, a2, a3, a4, a5, a6)
print('%.1f'%diem)

# %% [markdown]
# # Bài từ file: A5

# %%
a, b=map(int, input().split())
print(a**b)

# %% [markdown]
# # Bài từ file: A6

# %%
kitu=input()
print(ord(kitu))
kitu1=ord(kitu)+32
print(kitu1)

# %% [markdown]
# # Bài từ file: A7

# %%
a=((13**2)*3)+5
b=13**2*3+5
print(a, b)

# %% [markdown]
# # Bài từ file: A8

# %%
c=float(input())
f=1.8*c+32
print('%.2f'%f)

# %% [markdown]
# # Bài từ file: A9

# %%
x=int(input())
res=10+0.3*x+0.1*(x+0.3*x)
print('%.2f'%res)

# %% [markdown]
# # Bài từ file: Untitled

# %% [markdown]
# # Bài từ file: buoi 4

# %%
print('hello')
# Out:
# hello
